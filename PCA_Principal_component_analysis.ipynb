# %% [markdown]
# # importing the libraries

# %%
# importing the libraries
import os,sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings 
warnings.filterwarnings('ignore')
from scipy import stats

# %%
data=pd.read_csv(r'C:\Users\Admin\Desktop\it_VEDANT\My Learnbay Folder\My Learnbay Folder\Stat and ML by Utkarsha sir\ML_BY_ME\18th Feb 2023\Bank-data.csv',\
              index_col='Index'  )

# %%
data.head()
# Out:
#        interest_rate  credit  Gender  previous  duration Churn
# Index
# 0              1.334       0       1         0       117    no
# 1              0.767       0       0         1       274   yes
# 2              4.858       0       1         0       167    no
# 3              4.120       0       0         0       686   yes
# 4              4.856       0       1         0       159    no

# %%
data.isnull().sum()
# Out:
# interest_rate    0
# credit           0
# Gender           0
# previous         0
# duration         0
# Churn            0
# dtype: int64

# %%
### label encoder getdummies
data['Churn'].value_counts()
# Out:
# Churn
# no     259
# yes    259
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 518 entries, 0 to 517
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   interest_rate  518 non-null    float64
#  1   credit         518 non-null    int64
#  2   Gender         518 non-null    int64
#  3   previous       518 non-null    int64
#  4   duration       518 non-null    int64
#  5   Churn          518 non-null    object
# dtypes: float64(1), int64(4), object(1)
# memory usage: 28.3+ KB

# %%
data['Churn']=data['Churn'].astype('category')
data['Churn']=data['Churn'].cat.codes

# %%
data['Churn'].value_counts()
# Out:
# Churn
# 0    259
# 1    259
# Name: count, dtype: int64

# %%
### According to Alphabetical order it will take the categories.
### we can use label encoding also for this

# %%
### Independent Dep variable sepearation
x=data.drop('Churn',axis=1)
y=data['Churn']

# %%
x.head()
# Out:
#        interest_rate  credit  Gender  previous  duration
# Index
# 0              1.334       0       1         0       117
# 1              0.767       0       0         1       274
# 2              4.858       0       1         0       167
# 3              4.120       0       0         0       686
# 4              4.856       0       1         0       159

# %%
y.head()
# Out:
# Index
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# Name: Churn, dtype: int8

# %%
## Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=101)

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logit=LogisticRegression()

# %%
logit.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
## Training accuracy
from sklearn.metrics import accuracy_score,classification_report ,confusion_matrix
y_pred_train=logit.predict(x_train)
print('Training accuracy',accuracy_score(y_train,y_pred_train))
# Out:
# Training accuracy 0.8502415458937198

# %%
y_pred_test=logit.predict(x_test)
print('Training accuracy',accuracy_score(y_test,y_pred_test))
# Out:
# Training accuracy 0.8557692307692307

# %%
confusion_matrix(y_test,y_pred_test)
# Out:
# array([[51,  8],
#        [ 7, 38]], dtype=int64)

# %% [markdown]
# ### Using PCA

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA()

# %%
print(x_train.shape,x_test.shape)
# Out:
# (414, 5) (104, 5)

# %%
x_train_pca=pca.fit_transform(x_train)
x_test_pca=pca.transform(x_test)

# %%
print(x_train_pca.shape,x_test_pca.shape)
# Out:
# (414, 5) (104, 5)

# %%
print(x_train)
# Out:
#        interest_rate  credit  Gender  previous  duration
# Index
# 359            0.715       0       0         1        95
# 95             1.016       0       0         0       621
# 424            0.721       0       0         0       346
# 188            4.957       0       0         0      1806
# 24             4.865       0       1         1       293
# ...              ...     ...     ...       ...       ...
# 110            1.726       1       0         1       363
# 316            4.963       0       0         0       988
# 393            0.797       0       0         0       211
# 75             1.250       0       1         0       133
# 337            1.479       0       0         0       230
#
# [414 rows x 5 columns]

# %%
print(x_train_pca)
# Out:
# [[-2.99294757e+02  2.17679767e+00 -3.61552102e-01  6.60490521e-01
#   -8.86321197e-02]
#  [ 2.26705269e+02  1.81843660e+00 -2.39742418e-01 -2.98490283e-01
#   -7.49655721e-02]
#  [-4.82947365e+01  2.10664082e+00 -2.27429204e-01 -3.22793944e-01
#   -8.24645993e-02]
#  ...
#  [-1.83294735e+02  2.02787046e+00 -2.22059833e-01 -3.19263869e-01
#   -8.29776242e-02]
#  [-2.61294687e+02  1.58214930e+00  7.67989075e-01 -1.44248092e-01
#   -2.66895643e-02]
#  [-1.64294721e+02  1.34803509e+00 -2.24933899e-01 -2.71260377e-01
#   -7.29665623e-02]]

# %%
explained_var=pca.explained_variance_ratio_

# %%
print(explained_var)
# Out:
# [9.99969573e-01 2.78401657e-05 1.52357806e-06 7.81206924e-07
#  2.81663855e-07]

# %%
## PC1==>0.9995
## PC2===>0.0000435
## PC3===>0.000000271

# %%
pca_new=PCA(n_components=2)
x_train_pca=pca_new.fit_transform(x_train)
x_test_pca=pca_new.transform(x_test)

# %%
print(x_train_pca.shape,x_test_pca.shape)
# Out:
# (414, 2) (104, 2)

# %%
logit_1=LogisticRegression()
logit_1.fit(x_train_pca,y_train)
# Out:
# LogisticRegression()

# %%
## Training accuracy
y_pred_train=logit_1.predict(x_train_pca)
print('Training accuracy',accuracy_score(y_train,y_pred_train))
# Out:
# Training accuracy 0.8236714975845411

# %%
## Training accuracy
y_pred_test=logit_1.predict(x_test_pca)
print('Testing accuracy',accuracy_score(y_test,y_pred_test))
# Out:
# Testing accuracy 0.8269230769230769

# %%
confusion_matrix(y_test,y_pred_test)
# Out:
# array([[26, 33],
#        [20, 25]], dtype=int64)
