# %% [markdown]
# ![image.png](attachment:118c37ed-cfef-49f7-8b96-d5ce4170acbb.png)

# %% [markdown]
# <h1> This is heaDING </h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('titanic.csv')

# %%
df.columns
# Out:
# Index(['Cabin', 'Ticket', 'number', 'Survived'], dtype='object')

# %%
df.head()
# Out:
#   Cabin            Ticket number  Survived
# 0   NaN         A/5 21171      5         0
# 1   C85          PC 17599      3         1
# 2   NaN  STON/O2. 3101282      6         1
# 3  C123            113803      3         1
# 4   NaN            373450      A         0

# %%
df['number'].unique()
# Out:
# array(['5', '3', '6', 'A', '2', '1', '4'], dtype=object)

# %%
df['number'].value_counts()
# Out:
# number
# A    139
# 6    131
# 1    129
# 2    126
# 4    126
# 5    123
# 3    117
# Name: count, dtype: int64

# %%
df['number_num']=pd.to_numeric(df['number'],errors='coerce',downcast='integer')

# %%
df.head()
# Out:
#   Cabin            Ticket number  Survived  number_num
# 0   NaN         A/5 21171      5         0         5.0
# 1   C85          PC 17599      3         1         3.0
# 2   NaN  STON/O2. 3101282      6         1         6.0
# 3  C123            113803      3         1         3.0
# 4   NaN            373450      A         0         NaN

# %%
df['number_cat']=np.where(df['number_num'].isnull(),df['number'],np.nan)

# %%
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#                Cabin              Ticket number  Survived  number_num  \
# 0                NaN           A/5 21171      5         0         5.0
# 1                C85            PC 17599      3         1         3.0
# 2                NaN    STON/O2. 3101282      6         1         6.0
# 3               C123              113803      3         1         3.0
# 4                NaN              373450      A         0         NaN
# 5                NaN              330877      2         0         2.0
# 6                E46               17463      2         0         2.0
# 7                NaN              349909      5         0         5.0
# 8                NaN              347742      1         1         1.0
# 9                NaN              237736      A         1         NaN
# 10                G6             PP 9549      1         1         1.0
# 11              C103              113783      1         1         1.0
# ...

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Cabin       204 non-null    object
#  1   Ticket      891 non-null    object
#  2   number      891 non-null    object
#  3   Survived    891 non-null    int64
#  4   number_num  752 non-null    float64
#  5   number_cat  139 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 41.9+ KB

# %%
# str.extract
df['Cabin_num']=df['Cabin'].str.extract('(\d+)')

# %%
df['Cabin_cat']=df['Cabin'].str[0]

# %%
df.head()
# Out:
#   Cabin            Ticket number  Survived  number_num number_cat Cabin_num  \
# 0   NaN         A/5 21171      5         0         5.0        NaN       NaN
# 1   C85          PC 17599      3         1         3.0        NaN        85
# 2   NaN  STON/O2. 3101282      6         1         6.0        NaN       NaN
# 3  C123            113803      3         1         3.0        NaN       123
# 4   NaN            373450      A         0         NaN          A       NaN
#
#   Cabin_cat
# 0       NaN
# 1         C
# 2       NaN
# 3         C
# 4       NaN

# %%
import seaborn as sns
sns.catplot(data=df,x=df['Cabin_cat'],kind='count')

# %%
sns.__version__
# Out:
# '0.13.2'

# %%
df['Ticket'].unique()
# Out:
# array(['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450',
#        '330877', '17463', '349909', '347742', '237736', 'PP 9549',
#        '113783', 'A/5. 2151', '347082', '350406', '248706', '382652',
#        '244373', '345763', '2649', '239865', '248698', '330923', '113788',
#        '347077', '2631', '19950', '330959', '349216', 'PC 17601',
#        'PC 17569', '335677', 'C.A. 24579', 'PC 17604', '113789', '2677',
#        'A./5. 2152', '345764', '2651', '7546', '11668', '349253',
#        'SC/Paris 2123', '330958', 'S.C./A.4. 23567', '370371', '14311',
#        '2662', '349237', '3101295', 'A/4. 39886', 'PC 17572', '2926',
#        '113509', '19947', 'C.A. 31026', '2697', 'C.A. 34651', 'CA 2144',
#        '2669', '113572', '36973', '347088', 'PC 17605', '2661',
#        'C.A. 29395', 'S.P. 3464', '3101281', '315151', 'C.A. 33111',
#        'S.O.C. 14879', '2680', '1601', '348123', '349208', '374746',
# ...

# %%
df['Ticket_no']=df['Ticket'].apply(lambda s:s.split()[-1])

# %%
df.head()
# Out:
#   Cabin            Ticket number  Survived  number_num number_cat Cabin_num  \
# 0   NaN         A/5 21171      5         0         5.0        NaN       NaN
# 1   C85          PC 17599      3         1         3.0        NaN        85
# 2   NaN  STON/O2. 3101282      6         1         6.0        NaN       NaN
# 3  C123            113803      3         1         3.0        NaN       123
# 4   NaN            373450      A         0         NaN          A       NaN
#
#   Cabin_cat Ticket_no
# 0       NaN     21171
# 1         C     17599
# 2       NaN   3101282
# 3         C    113803
# 4       NaN    373450

# %%
df
# Out:
#                Cabin              Ticket number  Survived  number_num  \
# 0                NaN           A/5 21171      5         0         5.0
# 1                C85            PC 17599      3         1         3.0
# 2                NaN    STON/O2. 3101282      6         1         6.0
# 3               C123              113803      3         1         3.0
# 4                NaN              373450      A         0         NaN
# 5                NaN              330877      2         0         2.0
# 6                E46               17463      2         0         2.0
# 7                NaN              349909      5         0         5.0
# 8                NaN              347742      1         1         1.0
# 9                NaN              237736      A         1         NaN
# 10                G6             PP 9549      1         1         1.0
# 11              C103              113783      1         1         1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Cabin       204 non-null    object
#  1   Ticket      891 non-null    object
#  2   number      891 non-null    object
#  3   Survived    891 non-null    int64
#  4   number_num  752 non-null    float64
#  5   number_cat  139 non-null    object
#  6   Cabin_num   200 non-null    object
#  7   Cabin_cat   204 non-null    object
#  8   Ticket_no   891 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 62.8+ KB

# %%
df['Ticket_no']=pd.to_numeric(df['Ticket_no'],errors='coerce',downcast='integer')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Cabin       204 non-null    object
#  1   Ticket      891 non-null    object
#  2   number      891 non-null    object
#  3   Survived    891 non-null    int64
#  4   number_num  752 non-null    float64
#  5   number_cat  139 non-null    object
#  6   Cabin_num   200 non-null    object
#  7   Cabin_cat   204 non-null    object
#  8   Ticket_no   887 non-null    float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 62.8+ KB

# %%
df.head()
# Out:
#   Cabin            Ticket number  Survived  number_num number_cat Cabin_num  \
# 0   NaN         A/5 21171      5         0         5.0        NaN       NaN
# 1   C85          PC 17599      3         1         3.0        NaN        85
# 2   NaN  STON/O2. 3101282      6         1         6.0        NaN       NaN
# 3  C123            113803      3         1         3.0        NaN       123
# 4   NaN            373450      A         0         NaN          A       NaN
#
#   Cabin_cat  Ticket_no
# 0       NaN    21171.0
# 1         C    17599.0
# 2       NaN  3101282.0
# 3         C   113803.0
# 4       NaN   373450.0

# %%
df['Ticket_no'].unique()
# Out:
# array([2.117100e+04, 1.759900e+04, 3.101282e+06, 1.138030e+05,
#        3.734500e+05, 3.308770e+05, 1.746300e+04, 3.499090e+05,
#        3.477420e+05, 2.377360e+05, 9.549000e+03, 1.137830e+05,
#        2.151000e+03, 3.470820e+05, 3.504060e+05, 2.487060e+05,
#        3.826520e+05, 2.443730e+05, 3.457630e+05, 2.649000e+03,
#        2.398650e+05, 2.486980e+05, 3.309230e+05, 1.137880e+05,
#        3.470770e+05, 2.631000e+03, 1.995000e+04, 3.309590e+05,
#        3.492160e+05, 1.760100e+04, 1.756900e+04, 3.356770e+05,
#        2.457900e+04, 1.760400e+04, 1.137890e+05, 2.677000e+03,
#        2.152000e+03, 3.457640e+05, 2.651000e+03, 7.546000e+03,
#        1.166800e+04, 3.492530e+05, 2.123000e+03, 3.309580e+05,
#        2.356700e+04, 3.703710e+05, 1.431100e+04, 2.662000e+03,
#        3.492370e+05, 3.101295e+06, 3.988600e+04, 1.757200e+04,
#        2.926000e+03, 1.135090e+05, 1.994700e+04, 3.102600e+04,
#        2.697000e+03, 3.465100e+04, 2.144000e+03, 2.669000e+03,
# ...

# %%
df['Ticket_cat']=df['Ticket'].apply(lambda s:s.split()[0])

# %%
df
# Out:
#                Cabin              Ticket number  Survived  number_num  \
# 0                NaN           A/5 21171      5         0         5.0
# 1                C85            PC 17599      3         1         3.0
# 2                NaN    STON/O2. 3101282      6         1         6.0
# 3               C123              113803      3         1         3.0
# 4                NaN              373450      A         0         NaN
# 5                NaN              330877      2         0         2.0
# 6                E46               17463      2         0         2.0
# 7                NaN              349909      5         0         5.0
# 8                NaN              347742      1         1         1.0
# 9                NaN              237736      A         1         NaN
# 10                G6             PP 9549      1         1         1.0
# 11              C103              113783      1         1         1.0
# ...

# %%
df['Ticekt_cat1']=np.where(df['Ticket_cat'].str.isdigit(),np.nan,df['Ticket_cat'])

# %%
df.drop('Ticket_cat',inplace=True,axis=1)

# %%
df.head()
# Out:
#   Cabin            Ticket number  Survived  number_num number_cat Cabin_num  \
# 0   NaN         A/5 21171      5         0         5.0        NaN       NaN
# 1   C85          PC 17599      3         1         3.0        NaN        85
# 2   NaN  STON/O2. 3101282      6         1         6.0        NaN       NaN
# 3  C123            113803      3         1         3.0        NaN       123
# 4   NaN            373450      A         0         NaN          A       NaN
#
#   Cabin_cat  Ticket_no Ticekt_cat1
# 0       NaN    21171.0         A/5
# 1         C    17599.0          PC
# 2       NaN  3101282.0    STON/O2.
# 3         C   113803.0         NaN
# 4       NaN   373450.0         NaN

# %%
df.drop(['Cabin','Ticket'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   number  Survived  number_num number_cat Cabin_num Cabin_cat  Ticket_no  \
# 0      5         0         5.0        NaN       NaN       NaN    21171.0
# 1      3         1         3.0        NaN        85         C    17599.0
# 2      6         1         6.0        NaN       NaN       NaN  3101282.0
# 3      3         1         3.0        NaN       123         C   113803.0
# 4      A         0         NaN          A       NaN       NaN   373450.0
#
#   Ticekt_cat1
# 0         A/5
# 1          PC
# 2    STON/O2.
# 3         NaN
# 4         NaN

# %%
orderdf=pd.read_csv('orders.csv')

# %%
orderdf.head()
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157
# 2  2018-10-23        1859       25       1
# 3  2019-08-17        7292       25       1
# 4  2019-01-06        4344       25       3

# %%
orderdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   object
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
orderdf['date']=pd.to_datetime(orderdf['date'])

# %%
orderdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %%
orderdf['year']=orderdf['date'].dt.year

# %%
orderdf.head()
# Out:
#         date  product_id  city_id  orders  year
# 0 2019-12-10        5628       25       3  2019
# 1 2018-08-15        3646       14     157  2018
# 2 2018-10-23        1859       25       1  2018
# 3 2019-08-17        7292       25       1  2019
# 4 2019-01-06        4344       25       3  2019

# %%
orderdf['month']=orderdf['date'].dt.month
orderdf['month_name']=orderdf['date'].dt.month_name()

# %%
orderdf.head()
# Out:
#         date  product_id  city_id  orders  year  month month_name
# 0 2019-12-10        5628       25       3  2019     12   December
# 1 2018-08-15        3646       14     157  2018      8     August
# 2 2018-10-23        1859       25       1  2018     10    October
# 3 2019-08-17        7292       25       1  2019      8     August
# 4 2019-01-06        4344       25       3  2019      1    January

# %%
sns.catplot(data=orderdf,x='month_name',kind='count',col='year')

# %%
orderdf['day']=orderdf['date'].dt.day
orderdf['dayname']=orderdf['date'].dt.day_name()

# %%
orderdf.head()
# Out:
#         date  product_id  city_id  orders  year  month month_name  day  \
# 0 2019-12-10        5628       25       3  2019     12   December   10
# 1 2018-08-15        3646       14     157  2018      8     August   15
# 2 2018-10-23        1859       25       1  2018     10    October   23
# 3 2019-08-17        7292       25       1  2019      8     August   17
# 4 2019-01-06        4344       25       3  2019      1    January    6
#
#      dayname
# 0    Tuesday
# 1  Wednesday
# 2    Tuesday
# 3   Saturday
# 4     Sunday

# %%
orderdf['is_weekend']=np.where(orderdf['dayname'].isin(['Saturday','Sunday']),1,0)

# %%
orderdf
# Out:
#           date  product_id  city_id  orders  year  month month_name  day  \
# 0   2019-12-10        5628       25       3  2019     12   December   10
# 1   2018-08-15        3646       14     157  2018      8     August   15
# 2   2018-10-23        1859       25       1  2018     10    October   23
# 3   2019-08-17        7292       25       1  2019      8     August   17
# 4   2019-01-06        4344       25       3  2019      1    January    6
# 5   2018-08-23        1811       25       4  2018      8     August   23
# 6   2018-11-21        1282       26       1  2018     11   November   21
# 7   2019-03-27        5022        2      41  2019      3      March   27
# 8   2019-06-29        3699        3      15  2019      6       June   29
# 9   2018-08-30        4373       11       3  2018      8     August   30
# 10  2019-10-24        6339       26       1  2019     10    October   24
# 11  2019-08-02        3311       22       6  2019      8     August    2
# ...
